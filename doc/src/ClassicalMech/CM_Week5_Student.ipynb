# %% [markdown]
# ## Classical Mechanics - Week 5 Answers

# %% [markdown]
# ### Last Week:
#
# - Learn how to use the sympy package to set up equations
# - Plotted using sympy functions
# - Modeled the 3 types of harmonic oscillations
# -
#
# ### This Week:
# - Gain further experience with sympy
# - Derive equations using sympy
# - Pratice making functions with sympy

# %%
# Let's import packages, as usual
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym
sym.init_printing(use_unicode=True)

# %% [markdown]
# Using what we leared last week, please set up the following equation using sympy where $U(\vec{r})$ is our potential:
#
# $U(\vec{r}) = -e^{-(x^2+y^2)}$

# %%
x, y = sym.symbols('x, y')
U = -sym.exp(-(x**2 + y**2))
U
# Out:
#      2    2
#   - x  - y
# -ℯ

# %% [markdown]
# We have two ways in which we can graph this. Either perform the substitution $r^2 = x^2+y^2$ in order to plot in a 2D space or we could plot in a 3D space keeping $x$ and $y$ in our equation.
#
# ## Q1.) What do you think are the benefits/draw-backs of these two methods of analyzing our equation? Which do you prefer?

# %% [markdown]
# &#9989; Double click this cell, erase its content, and put your answer to the above question here.

# %% [markdown]
# #### Now let's graph the potential
# For now we will use sympy to perform both a 2D and 3D plot. Let's do the 2D version first using what we learned from the last notebook!

# %%
## Put your code for potential graphing here

# %% [markdown]
# ## Q2.) What can you extrapolate from this 2D graph?

# %% [markdown]
# &#9989; Double click this cell, erase its content, and put your answer to the above question here.

# %% [markdown]
# The cell below imports function from the sympy package that allows us to graph in 3D. Using the "plot3d" call, make a 3D plot of our originally initalized equation.
#
# This time, try setting the x and y plot limits as close as you can to the origin while having a clear picture of what is happening to the origin. For example x and y could range from (-4,4). (Google/Bing/DuckDuckGo/whatever is your friend in figuring out how to use "plot3d" if you can't figure it out initially. HINT: You can use the function exactly like sym.plot())

# %%
# The below import will allow us to plot in 3D with sympy
from sympy.plotting import plot3d

# %%
plot3d(U,(x,-2,2),(y,-2,2))

# %% [markdown]
# ## Q3.) What can you extrapolate from this 2D graph?

# %% [markdown]
# &#9989; Double click this cell, erase its content, and put your answer to the above question here.

# %% [markdown]
# Now let's graph a potential that is a bit more complicated:
#
# $U(\vec{r}) = -e^{-(4x^2+2y^2)}$
#
# As we can see, our total distance $r$ isn't quite as obvious to insert as before, the $x$ and $y$ component affecting our potential in different amounts. Make a 3D plot and observe how it is different from before.

# %%
## Put your code for graphing the potential here

# %% [markdown]
# ## Q4.) How does this new potential compare to the original? (Feel free to make the graph's x and y-range smaller to observe the differences)

# %% [markdown]
# &#9989; Double click this cell, erase its content, and put your answer to the above question here.

# %% [markdown]
# ##### Let's get some more in-depth coding experience:
# Try to graph this last potential using what we learned from the first three weeks of class, not using sympy.
#
# $U(r) = 3.2\dot{}e^{-(0.5x^2+0.25y^3)}$
#
# Feel free to look back at the previous notebooks to get your bearings again and Google/Bing/DuckDuckGo/whatever to search how to 3D plot. To help start you off, the below cell contains the package you need to plot in 3D.

# %%
# Useful package and function for plotting in 3D
from mpl_toolkits import mplot3d

# %%
# Put your code for plotting in 3D here

# %% [markdown]
# ## Q5.) How would you describe the new potential?

# %% [markdown]
# &#9989; Double click this cell, erase its content, and put your answer to the above question here.

# %% [markdown]
# ### Try this:
# Center the new potential at (1,1) instead of (0,0).

# %%
## Put your code for plotting in 3D here

# %% [markdown]
# ## Q6.) How did you move the peak of the graph?

# %% [markdown]
# &#9989; Double click this cell, erase its content, and put your answer to the above question here.

# %% [markdown]
# # Notebook Wrap-up.
# Run the cell below and copy-paste your answers into their corresponding cells.

# %%
from IPython.display import HTML
HTML(
"""
<iframe 
	src="https://goo.gl/forms/2Ax1XFtWZhjJOHym2" 
	width="100%" 
	height="1200px" 
	frameborder="0" 
	marginheight="0" 
	marginwidth="0">
	Loading...
</iframe>
"""
)

# %% [markdown]
# # Congrulations! Another week completed!
#
# Don't be shy to practice things you are having a bit of a hard time with, or maybe you are getting everything that's being taught. Working with packages can be tricky and even confusing at first, but with more practice it'll get easier. Either way, it's really your call what you want to do now: relax, study, drink tea, etc.
